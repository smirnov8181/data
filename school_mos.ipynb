# %%
import pandas as pd

# %%
# !dir
# Out:
#  ’®¬ ў гбва®©бвўҐ C Ё¬ҐҐв ¬ҐвЄг OS
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : C4E4-7C29
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ c:\projects\data
#
# 25.12.2018  16:29    <DIR>          .
# 25.12.2018  16:29    <DIR>          ..
# 25.12.2018  16:29    <DIR>          .ipynb_checkpoints
# 18.12.2018  17:23         3я504я517 bus_stops.csv
# 25.12.2018  14:43            20я701 Data Lesson 2.ipynb
# 20.12.2018  13:19    <DIR>          env
# 20.12.2018  14:22         2я456я762 Lesson 1.ipynb
# 25.12.2018  16:20            53я259 lesson2_part2.ipynb
# 25.12.2018  16:29         7я509я307 school_mos.csv
# 25.12.2018  16:28                72 school_mos.ipynb
# 20.12.2018  13:38    <DIR>          something
#                6 д ©«®ў     13я544я618 Ў ©в
#                5 Ї Ї®Є   6я657я982я464 Ў ©в бў®Ў®¤­®

# %%
schools = pd.read_csv(open('school_mos.csv', 'r', encoding="UTF-8"), sep=';')

# %%
schools.head(5)
# Out:
#                         ShortName  \
# 0         ГБОУ ДО ДТДМ «Хорошево»
# 1                   ГБОУ ГМЦ ДОгМ
# 2   ГБУ «Лаборатория путешествий»
# 3        ГБПОУ колледж «Царицыно»
# 4  ГБОУДО «ДТДиМ «Преображенский»
#
#                                             FullName  \
# 0  Государственное бюджетное образовательное учре...
# 1  Государственное бюджетное образовательное учре...
# 2  Государственное бюджетное учреждение города Мо...
# 3  Государственное бюджетное профессиональное обр...
# 4  Государственное бюджетное образовательное учре...
#
#                            LicensingAndAccreditation EducationalServices  \
# 0  Признак наличия лицензии у ОУ: да\nСерия бланк...                 NaN
# 1  Признак наличия лицензии у ОУ: да\nСерия бланк...                 NaN
# 2  Признак наличия лицензии у ОУ: да\nСерия бланк...                 NaN
# 3  Признак наличия лицензии у ОУ: да\nСерия бланк...                 NaN
# ...

# %%
type(schools)
# Out:
# pandas.core.frame.DataFrame

# %%
name = schools.groupby(['Number']).sum()
name
# Out:
#         IDEKIS          INN         KPP            OGRN   global_id
# Number
# 1.0      40236  23169545399  2316903003   3123221671416  2237446221
# 2.0      26416  15418364130  1541802002   2085443630655  1758004443
# 3.0      11681   7709438340   770901001   1057709052290   832654500
# 4.0      12896   7705513678   770501001   1057705001970   879263954
# 5.0      13137   7718232530   771801001   1037718002805   886797905
# 7.0      26883  15479136500  1547902002   2085482870614  1503532003
# 8.0      12017   7714805691   771401001   1107746276659   901672696
# 9.0      11686   7713385719   771301001   1047713057688   865082823
# 10.0     26277  15434608049  1543402002   2095452544636  1751880712
# 11.0     26025  15474258496  1547402002   2085443555822  1333161076
# 14.0     13173   7729423688   772901001   1037700000645   666580376
# 15.0      9291   7728013054   772801001   1037739321817   666580546
# 17.0     22720  15456144497  1545602002   2065439961453  1333160988
# ...

# %%
name
# Out:
#                                                 IDEKIS  Number          INN  \
# ShortName
# ГАОУ «Школа № 1518»                              13863  1518.0   7717666051
# ГАОУ ВО МГПУ                                     13270     0.0   7717043346
# ГАОУ ДПО «ТемоЦентр»                             13107     0.0   7718924940
# ГАОУ ДПО МЦКО                                    13111     0.0   7725539709
# ГАОУ ДПО МЦРКПО                                  13944     0.0   7714239823
# ГАОУ ДПО ЦПМ                                     13070     0.0   7725618950
# ГАОУ школа «ШИК 16»                              13761     0.0   7717025259
# ГАОУ школа № 1306 - «Школа молодых политиков»    13930  1306.0   7729413009
# ГАОУ школа № 548                                 13866   548.0   7737027335
# ГАПОУ КП № 11                                    12887    11.0   7743085712
# ГАПОУ МОК им. В. Талалихина                      12679     0.0   7723920242
# ...

# %%
type(schools)
# Out:
# pandas.core.frame.DataFrame
